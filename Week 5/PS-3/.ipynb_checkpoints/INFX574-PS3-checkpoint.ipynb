# %% [markdown]
# # Problem Set 3, due February 5 at 5:30 pm
#
# ###Before You Start
#
# Make sure the following libraries load correctly (hit Ctrl-Enter). Note that while you are loading several powerful libraries, including machine learning libraries, the goal of this problem set is to implement several algorithms from scratch. In particular, you should *not* be using any built-in libraries for nearest neighbors, distance metrics, or cross-validation -- your mission is to write those algorithms in Python! Parts 1 and 2 will be relatively easy; Part 3 will take more time.
#
# *Also note:* For this assignment we are requiring you to use base **matplotlib** - no more Seaborn or other packages. This will help you become familiar with techniques for maintaining fine-grained control over your data visualizations. It will also help our graders, who spent countless hours trying to make various versions import for grading.

# %%
import IPython
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib
import sklearn

# %% [markdown]
# ---
#
# ## Introduction to the assignment
#
# For this assignment, you will be using the Boston Housing Prices Data Set.  This used to be housed by [UCI Machine Learning Repository](http://archive.ics.uci.edu/ml/datasets/Housing), but it is not housed there any more. You can read about it at [Kaggle](https://www.kaggle.com/vikrishnan/boston-house-prices) and at the [University of Toronto](https://www.cs.toronto.edu/~delve/data/boston/bostonDetail.html). Please read about the dataset carefully before continuing.  Use the following commands to load the dataset:

# %% [markdown]
# ## Note to TA : ** I collaborated with Vishal Khatri on this assignment **

# %%
from sklearn.datasets import load_boston
bdata = load_boston()

# %% [markdown]
# The following commands will provide some basic information about the shape of the data:

# %%
print(bdata.keys())
print(bdata.feature_names)
print(bdata.data.shape)
print(bdata.target.shape)
# uncomment the following if you want to see a lengthy description of the dataset
print(type(bdata.target))
print(bdata.DESCR)
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']
# (506, 13)
# (506,)
# <class 'numpy.ndarray'>
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
# ...

# %% [markdown]
# ---
#
# ##Part 1: Descriptive analysis
#
# Before beginning the "real" work, dig into the data a bit do see what you're dealing with.  If you feel that you are still in the beginning stages of analyzing data in Python, no problem. That is understandable. Just make sure to read some of the online resources like [this one](https://github.com/jrjohansson/scientific-python-lectures).
#
# ###1.1: Histogram of housing prices
#
# Below you will find some very basic code to make a very basic histogram of median housing prices (the "target" variable) for your dataset.  Your first task is to make this graph look pretty by doing the following:
#
# 1. Add appropriate labels to the x and y axes, make sure to include units
# 2. Change the bin width on the histogram to be $1000
# 3. Remove the axes on the top and right side of the plot window
# 4. Change the color of the bars to be green, and remove the black borders from the bars

# %%
# prepare your jupyter notebook to work with matplotlib and import the library to something convenient
# %matplotlib inline  
import matplotlib.pyplot as plt  

# edit the code below to make the graph look good
min_val = 0
max_val = 0
new_arr = bdata.target * 1000
for item in bdata.target:
    if (item > max_val):
        max_val = item
    
    if(item < min_val):
        min_val = item

fig = plt.figure(figsize=(30,10))
ax = fig.add_subplot(111)
ax.set_xlabel('Median value of owner-occupied homes in $', fontsize=20)
ax.set_ylabel('Frequency', fontsize=30)
ax.set_title('Histogram of Median value (in $) of owner-occupied homes', fontsize = 30)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.hist(new_arr, color='g', bins = range(int(min_val * 1000) , int(max_val * 1000) , 1000))
plt.show()

# %% [markdown]
# ###1.2: Scatter plot of housing prices and crime
#
# Use matplotlib to create a scatter plot that shows the relationship between the median value of the home (y-axis) and the per-capita crime rate (x-axis).  Properly label your axes, and make sure that your graphic looks polished and professional.

# %%
# enter your code below
df = pd.DataFrame(bdata.data , columns = bdata.feature_names)
df['MEDV'] = pd.Series(bdata.target)
figure = plt.figure(figsize=(10,8))
axes = figure.add_subplot(111)
axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
axes.set_xlabel('Per-Capita Crime Rate', fontsize=13)
axes.set_ylabel('Median value of owner-occupied homes in $1000', fontsize=13)
axes.set_title('Per-Capita Crime Rate vs Median value of owner-occupied homes', fontsize = 15)
plt.scatter(df['CRIM'], df['MEDV'])

# %% [markdown]
# ###1.3 Create your own (creative and effective) visualization
#
# Use another type of graph or chart to illustrate an interesting pattern in the data.  Be creative in your visualization, and make sure to produce a "publication-quality" graph.  Points will be given for useful and creative graphs; points will be deducted for confusing issues like unlabeled axes.  If you're new to data visualization, [this guide](http://pubs.aeaweb.org/doi/pdfplus/10.1257/jep.28.1.209) is a good place to start.

# %%
# enter your code here
#Plot 1
figure = plt.figure(figsize=(15,15))
axes = figure.add_subplot(221)

axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
axes.set_xlabel('Nitric oxides concentration (parts per 10 million)', fontsize=11)
axes.set_ylabel('Median value of owner-occupied homes in $1000', fontsize=11)
axes.set_title('NOX vs Median value of homes', fontsize = 15)
plt.scatter(df['NOX'], df['MEDV'], marker = 'x', color = 'm')

#Plot 2
axes = figure.add_subplot(222)
axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
axes.set_xlabel('Weighted distances to 5 Employment centres', fontsize=11)
axes.set_ylabel('Median value of owner-occupied homes in $1000', fontsize=11)
axes.set_title('Distance vs Median value of homes', fontsize = 15)
plt.scatter(df['DIS'], df['MEDV'], marker = 'v', color = 'b')

#Plot 3
axes = figure.add_subplot(223)
axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
axes.set_xlabel('Pupil-Teacher ratio by town', fontsize=11)
axes.set_ylabel('Median value of owner-occupied homes in $1000', fontsize=11)
axes.set_title('Pupil-Tecaher Ratio vs Median value of homes', fontsize = 15)
plt.scatter(df['PTRATIO'], df['MEDV'], marker = 'v', color = 'b')

#Plot 4
axes = figure.add_subplot(224)
axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
axes.set_xlabel('% of owner-occupied units built prior to 1940', fontsize=11)
axes.set_ylabel('Median value of owner-occupied homes in $1000', fontsize=11)
axes.set_title('Proportion Owner Occupied Units vs Median value homes', fontsize = 15)
plt.scatter(df['AGE'], df['MEDV'], marker = 'x', color = 'm')

# %% [markdown]
# ---
#
# ##Part 2: Experimental Setup
#
# The goal of the next few sections is to design an experiment to predict the median home value for an instance in the data.
#
# ###2.1 Begin by writing a function to compute the Root Mean Squared Error for a list of numbers
#
# You can find the sqrt function in the Numpy package. Furthermore the details of RMSE can be found on [Wikipedia](http://en.wikipedia.org/wiki/Root-mean-square_deviation)

# %%
"""
Function
--------
compute_rmse

Given two arrays, one of actual values and one of predicted values,
compute the Roote Mean Squared Error

Parameters
----------
predictions : array
    Array of numerical values corresponding to predictions for each of the N observations

yvalues : array
    Array of numerical values corresponding to the actual values for each of the N observations

Returns
-------
rmse : int
    Root Mean Squared Error of the prediction

Example
-------
>>> print compute_rmse((2,2,3),(0,2,6)
2.16
"""
def compute_rmse(predictions, yvalues):
    rmse = np.sqrt(np.mean((np.array(predictions) - np.array(yvalues))**2))
    return rmse

print(compute_rmse((2,2,3),(0,2,6)))
# Out:
# 2.0816659994661326

# %% [markdown]
# ###2.2 Divide your data into training and testing datasets
#
# Randomly select 66% of the data and put this in a training dataset (call this "bdata_train"), and place the remaining 34% in a testing dataset (call this "bdata_test")

# %%
# leave the following line untouched, it will help ensure that your "random" split is the same "random" split used by the rest of the class
np.random.seed(seed=13579)
# enter your code here
num_of_rows = df.shape[0]
test_size = int(num_of_rows * 0.66)
df_test_indices = np.random.choice(range(0, num_of_rows), size = test_size, replace=False)

#train-data
bdata_train = df.iloc[df_test_indices,]

#test-data
bdata_test = df.iloc[~df.index.isin(df_test_indices), ]

# %% [markdown]
# ###2.3 Use a very bad baseline for prediction, and compute RMSE
#
# Create a model that predicts, for every observation x_i, that the median home value is the average (mean) of the median values for all instances in the training set.  Compute the RMSE on the training set.  Now compute the RMSE on the test data set (but use the model you trained on the training set!).  How does RMSE compare for training vs. testing datasets? Is this what you expected, and why?

# %%
# enter your code here

meanOfTrainTarget = np.mean(bdata_train['MEDV'])

def mean_model(target):
    return compute_rmse(meanOfTrainTarget, target)

print('RMSE for training data :', mean_model(bdata_train['MEDV']))
print('RMSE for test data :', mean_model(bdata_test['MEDV']))
# Out:
# RMSE for training data : 8.584967883775533
# RMSE for test data : 10.281671624776735

# %% [markdown]
# **Answer: The RMSE value from the test data is higher than the RMSE value from the training data. This was somewhat expected because we have a bad model for prediction and our model is not considering any features from the dataset**

# %% [markdown]
# ---
#
# ##Part 3: Nearest Neighbors

# %% [markdown]
# ###3.1 Nearest Neighbors: Distance function
# Let's try and build a machine learning algorithm to beat the "Average Value" baseline that you computed above.  Soon you will implement the Nearest Neighbor algorithm, but first you need to create a distance metric to measure the distance (and similarity) between two instances.  Write a generic function to compute the L-Norm distance (called the [*p*-norm](http://en.wikipedia.org/wiki/Norm_(mathematics) distance on Wikipedia). Verify that your function works by computing the Euclidean distance between the points (3,4) and (6,8).

# %%
"""
Function
--------
distance

Given two instances and a value for L, return the L-Norm distance between them

Parameters
----------
x1, x2 : array
    Array of numerical values corresponding to predictions for each of the N observations

L: int
    Value of L to use in computing distances

Returns
-------
dist : int
    The L-norm distance between instances

Example
-------
>>> print distance((3,4),(6,8),2)
7

"""
def distance(x1, x2, L):
    #your code here 
    if L == 0:
        return 1
    x1 = np.asarray(x1)
    x2 = np.asarray(x2)
    act_dis = np.abs(x2 - x1)**L
    if act_dis.ndim == 1:
        dist = (np.sum(act_dis))**(1/L)
    else:
        dist = (np.sum(act_dis, axis=1))**(1/L)
    return dist.astype(int)

L_NORM_DIST = distance((3,4),(6,8),2)
L_NORM_DIST
# Out:
# 5

# %% [markdown]
# ###3.2 Basic Nearest Neighbor algorithm
#
# Now things get fun.  Your task is to implement a basic nearest neighbor algorithm from scratch.  Your simple model will use two input features (CRIM and RM) and a single output (MEDV).  In other words, you are modelling the relationship between median home value and crime rates and house size.
#
# Use your training data (bdata_train) to "fit" your model, although as you know, with Nearest Neighbors there is no real training, you just need to keep your training data in memory.  Write a function that predicts, for each instance in the testing data (bdata_test), the median home value using the nearest neighbor algorithm we discussed in class.  Since this is a small dataset, you can simply compare your test instance to every instance in the training set, and return the MEDV value of the closest training instance.  Have your function take L as an input, where L is passed to the distance function.
#
# Compute the RMSE for the Nearest Neighbor predictions on the test set, using the Euclidean distance.  Report an estimate of the total time taken by your code to predict the nearest neighbors for all the values in the test data set.

# %%
import time
def nneighbor(train_data_set, test_data_set, col_indices, target, L, k=1):
    start_time = time.time()
    final = []
    for i in range(len(test_data_set)):
        cal_dist = distance(train_data_set.iloc[:,col_indices].values, test_data_set.iloc[i,col_indices].values, L) 
        cal_dist = cal_dist[:, np.newaxis]
        cal_dist = np.append(cal_dist, train_data_set.iloc[:,target],1)
        min_Val = cal_dist[0][0]
        min_Val_Row = cal_dist[0]
        for val in cal_dist:
            if val[0] < min_Val:
                min_Val = val[0]
                min_Val_Row = val
        final.append(min_Val_Row)
    
    final2 = np.array(final)
    final2 = np.append(final2, test_data_set.iloc[:, target], axis = 1)
    rmse = compute_rmse(final2[:,1], final2[:,2])
    print ('Time Taken is to run nneighbor : ' + str(time.time() - start_time) + '\n')
    return rmse

print (nneighbor(bdata_train, bdata_test,[0,5],[13],2))
# Out:
# Time Taken is to run nneighbor : 0.37131667137145996
#
# 8.529459320530114

# %% [markdown]
# ###3.3 Results and Normalization
#
# If you were being astute, you would have noticed that we never normalized our features -- a big no-no with Nearest Neighbor algorithms.  Write a generic normalization function that takes as input an array of values for a given feature, and returns the normalized array (subtract the mean and divide by the standard deviation).
#
# Re-run the Nearest Neighbor algorithm on the normalized dataset (still just using CRIM and RM as input), and compare the RMSE from this method with your previous RMSE evaluations.
#
# *NOTE*: To normalize properly, best practice is to compute the mean and standard deviation on the training set, and use these values to normalize the testing dataset. However, for this problem set, it is okay if you separately normalize each dataset using the respective mean and standard deviation.

# %%
"""
# 

Function
--------
normalize

Nomalizing values of a series

Parameters
----------
raw_data : Pandas Dataframe
    data to nromaize

Returns
-------
normalized_data : Dataframe
    The Root mean square error

Example
-------
>>> normalize(bdata_train['CRIM'])


"""
def normalize(raw_data):
    #your code here
    normalized_data = (np.subtract(raw_data, np.mean(raw_data)) / np.std(raw_data)).values
    return normalized_data

normalized_bdata_training = bdata_train.assign(CRIM = normalize(bdata_train['CRIM']), RM=normalize(bdata_train['RM']), MEDV = normalize(bdata_train['MEDV']))
normalized_bdata_test = bdata_test.assign(CRIM = normalize(bdata_test['CRIM']), RM=normalize(bdata_test['RM']), MEDV = normalize(bdata_test['MEDV']))
print(nneighbor(normalized_bdata_training, normalized_bdata_test, [0,5],[13], 2))
# Out:
# Time Taken is to run nneighbor : 0.34262681007385254
#
# 0.8142267854185724

# %% [markdown]
# **Answer: We can see that the RMSE value after normalization is lower than the RMSE without normalization**

# %% [markdown]
# ###3.4 Optimization
#
# A lot of the decisions we've made so far have been arbitrary.  Try to increase the performance of your nearest neighbor algorithm by adding features that you think might be relevant, and by using different values of L in the distance function.  Try a model that uses a different set of 2 features, then try at least one model that uses more than 4 features, then try using a different value of L.  If you're having fun, try a few different combinations of features and L!
#
# What combination of features and distance function provide the lowest RMSE?  Do your decisions affect the running time of the algorithm?

# %%
# Model with different 2 features - RM and NOX
normalized_bdata_train1 = bdata_train.assign(RM = normalize(bdata_train['RM']), NOX = normalize(bdata_train['NOX']), 
                                             MEDV = normalize(bdata_train['MEDV']))
normalized_bdata_test1 = bdata_test.assign(RM = normalize(bdata_test['RM']), NOX = normalize(bdata_test['NOX']),
                                           MEDV = normalize(bdata_test['MEDV']))

print('Model using 2 features gives an RMSE of ', nneighbor(normalized_bdata_train1, normalized_bdata_test1, [4,5],[13],2))

# 1. Model with 5 features - CRIM,RM,NOX,RAD,DIS
normalized_bdata_train2 = bdata_train.assign(CRIM = normalize(bdata_train['CRIM']), RM = normalize(bdata_train['RM']),
                                             NOX = normalize(bdata_train['NOX']), RAD = normalize(bdata_train['RAD']),
                                             DIS = normalize(bdata_train['DIS']), MEDV = normalize(bdata_train['MEDV']))
normalized_bdata_test2 = bdata_test.assign(CRIM = normalize(bdata_test['CRIM']), RM = normalize(bdata_test['RM']),
                                           NOX = normalize(bdata_test['NOX']), RAD = normalize(bdata_test['RAD']),
                                           DIS = normalize(bdata_test['DIS']), MEDV = normalize(bdata_test['MEDV']))

print('Model using 5 features gives an RMSE of' , nneighbor(normalized_bdata_train2, normalized_bdata_test2, [0,4,5,7,8],[13],2))

# 2. Model with different 5 features - TAX, RM, NOX, RAD, DIS
normalized_bdata_train3 = bdata_train.assign(TAX = normalize(bdata_train['TAX']), RM = normalize(bdata_train['RM']),
                                             NOX = normalize(bdata_train['NOX']), RAD = normalize(bdata_train['RAD']),
                                             DIS = normalize(bdata_train['DIS']), MEDV = normalize(bdata_train['MEDV']))
normalized_bdata_test3 = bdata_test.assign(TAX = normalize(bdata_test['TAX']), RM = normalize(bdata_test['RM']),NOX = normalize(bdata_test['NOX']), RAD = normalize(bdata_test['RAD']),DIS = normalize(bdata_test['DIS']), MEDV = normalize(bdata_test['MEDV']))

print('Model using different 5 features gives an RMSE of' , nneighbor(normalized_bdata_train2, normalized_bdata_test2, [9,4,5,7,8],[13],2))


# Model with 5 features and different L-NORM
print('Model using 5 features and a different L value gives an RMSE of', nneighbor(normalized_bdata_train2, normalized_bdata_test2, [0,4,5,7,8],[13],1))
# Out:
# Time Taken is to run nneighbor : 0.3530254364013672
# Model using 2 features gives an RMSE of  0.9337215657434482
# Time Taken is to run nneighbor : 0.36978602409362793
# Model using 5 features gives an RMSE of 0.8798702383384189
# Time Taken is to run nneighbor : 0.3676450252532959
# Model using different 5 features gives an RMSE of 0.862445492389953
# Time Taken is to run nneighbor : 0.38739919662475586
# Model using 5 features and a different L value gives an RMSE of 0.8236097823908811

# %% [markdown]
# **Answer: I see that the 5 features, CRIM, RM, NOX, RAD and DIS, with a L value of 1 gives me the lowest RMSE value of 0.823. The running time increases slightly as the number of features included in the model increases.**

# %% [markdown]
# ### 3.5 Cross-Validation
#
# The more you tinkered with your features and distance function, the higher the risk that you overfit your training data.  To prevent this sort of overfitting, you need to use cross-validation (see K-fold [cross-validation](http://en.wikipedia.org/wiki/Cross-validation_(statistics)).  Here you must implement a simple k-fold cross-validation algorithm yourself.  The function you write here will be used several more times in this problem set, so do your best to write efficient code! (Note that the sklearn package has a built-in [K-fold](http://scikit-learn.org/stable/modules/cross_validation.html#cross-validation) iterator -- you should *not* be invoking that or any related algorithms in this section of the problem set.)
#
# Use 10-fold cross-validation and report the average RMSE for Nearest Neighbors using Euclidean distance with CRIM and RM input features, as well as the total running time for the full run of 10 folds.  In other words, randomly divide your dataset into 10 equally-sized samples, and for each of 10 iterations (the "folds"), use 9 samples as "training data" (even though there is no training in k-NN!), and the remaining 1 sample for testing.  Compute the RMSE of that particular test set, then move on to the next iteration.  Report the average RMSE across the 10 iterations.

# %%
# indices of k-fold data
def partition(l, n):
    for i in range(0, len(l), n):
        yield l[i:i+n]

# K-fold cross validation function 
def kfoldcv(function, data, K, L, col_num, target, k = 1):
    start_time = time.time()
    buckets = list(partition(list(range(len(data))),int(len(data)/K)))
    if len(buckets) > K:
        buckets[K-1] = buckets[K-1] + buckets[K]
        buckets.remove(buckets[K])
     
    rmse = []
    
    for i in range(K):
        test_ind = buckets[i]
        train_ind = range(len(data))
        train_ind = [elem for elem in train_ind if elem not in test_ind]
        train = data.iloc[train_ind,:]
        test = data.iloc[test_ind,:]
        rmse.append(function(train, test, col_num, target, L, k))
    print ('Average RMSE is ', str(np.mean(rmse)))
    return np.mean(rmse)
    
# Normalize data
normalized_bdata = df.assign(CRIM = normalize(df['CRIM']), RM = normalize(df['RM']), MEDV = normalize(df['MEDV']))
np.random.seed(seed = 13579)
normalized_bdata = normalized_bdata.reindex(np.random.permutation(normalized_bdata.index))

# passing normalized data through K-fold cross validation and using the 'neighbor' function
print ('Output of 10-fold cross validation using CRIM and RM: \n')
print (kfoldcv(nneighbor, normalized_bdata, 10,2,[0,5], [13]))
# Out:
# Output of 10-fold cross validation using CRIM and RM:
#
# Time Taken is to run nneighbor : 0.08671188354492188
#
# Time Taken is to run nneighbor : 0.11709475517272949
#
# Time Taken is to run nneighbor : 0.11667823791503906
#
# Time Taken is to run nneighbor : 0.10181188583374023
#
# Time Taken is to run nneighbor : 0.12261795997619629
#
# Time Taken is to run nneighbor : 0.1087942123413086
#
# Time Taken is to run nneighbor : 0.11311721801757812
#
# Time Taken is to run nneighbor : 0.11661911010742188
#
# Time Taken is to run nneighbor : 0.09937429428100586
#
# Time Taken is to run nneighbor : 0.10601568222045898
#
# Average RMSE is  0.7294003791825324
# 0.7294003791825324

# %% [markdown]
# ###3.6 K-Nearest Neighbors Algorithm
#
# Implement the K-Nearest Neighbors algorithm.  Using 10-fold cross validation, report the RMSE for K=3 and the running time of the algorithm.

# %%
"""

Function
--------
knn

K-Nearest Neighbors algorithm

Parameters
----------
train, test : Pandas Dataframe
    Training and Test dataset

col_num: list
    indices of the features to be selected from the training/test data

target : Series
    The target feature 

L: int
    L value for L-norm. Example: 2

Returns
-------
rmse : int
    The Root mean square error

Example
-------
>>> print(knn(normalized_bdata_train1, normalized_bdata_test1, [0,5], [13], 2, 5)
0.6790713074099141

"""
def knn(train, test, col_num, target, L, K):
    
    final = []
    for j in range(len(test)):
        dist = distance(train.iloc[:,col_num], test.iloc[j,col_num], L)        
        dist = dist[:, np.newaxis]
        dist2 = np.append(dist, train.iloc[:,target],1)
        sortd = dist2[np.argsort(dist2[:,0]),:]
        final.append(np.mean(sortd[0:K], axis = 0))
       
    final = np.array(final)    
    final2 = np.append(final, test.iloc[:,target],1)
    rmse = compute_rmse(final2[:,1], final2[:,2])
    return rmse

normalized_bdata = df.assign(CRIM = normalize(df['CRIM']), RM = normalize(df['RM']), MEDV = normalize(df['MEDV']))
np.random.seed(seed = 13579)
normalized_bdata = normalized_bdata.reindex(np.random.permutation(normalized_bdata.index))
start_time = time.time()
print ('RMSE for K=3' , knn(normalized_bdata_training, normalized_bdata_test, [0,5], [13], 2, 3))
print('Time taken to run', str( time.time()-start_time))
# Out:
# RMSE for K=3 0.6672953261316146
# Time taken to run 0.33373165130615234

# %% [markdown]
# ###3.7 Using cross validation to find K
#
# What is the best choice of K?  Compute the RMSE for values of K between 1 and 25 using 10-fold cross-validation.  Use the following features in your model, and don't forget to normalize: CRIM, ZN, RM, AGE, DIS, TAX.  Create a graph that shows how RMSE changes as K increases from 1 to 25.  Label your axes, and summarize what you see.  What do you think is a reasonable choice of K for this model?

# %%
# enter your code here
normalized_bdata = df.assign(TAX = normalize(df['TAX']), RM = normalize(df['RM']),
                                             CRIM = normalize(df['CRIM']), RAD = normalize(df['AGE']),
                                             DIS = normalize(df['DIS']), ZN = normalize(df['ZN']), 
                                    MEDV = normalize(df['MEDV']))

rmse = []
minRMSE = kfoldcv(knn, normalized_bdata, 10, 2, [0,1,5,6,7,9], [13], 1) # kn
rmse.append(minRMSE)
#new_data = normalize2(data)
for i in range(1,25):
    rmse.append(kfoldcv(knn, normalized_bdata, 10, 2, [0,1,5,6,7,9], [13], i+1))
    if minRMSE > rmse[i]:
        minRMSE = rmse[i]
        ind = i+1
print ('The best value of K for KNN classifier for this data is :', str(ind))
# Out:
# Average RMSE is  0.9148799941367336
# Average RMSE is  0.8349915078715746
# Average RMSE is  0.7989743760183126
# Average RMSE is  0.7720623254984087
# Average RMSE is  0.7648231156228829
# Average RMSE is  0.7694861619152008
# Average RMSE is  0.7747811020534557
# Average RMSE is  0.781081622919919
# Average RMSE is  0.7899629449157357
# Average RMSE is  0.793657273154624
# Average RMSE is  0.8013688655102742
# Average RMSE is  0.8099392709128133
# Average RMSE is  0.8123943239777569
# Average RMSE is  0.8136291891194647
# Average RMSE is  0.8204536133538853
# Average RMSE is  0.8216692574882828
# Average RMSE is  0.8216729387726188
# Average RMSE is  0.8244191812877855
# Average RMSE is  0.8290958907316078
# Average RMSE is  0.8298145805348179
# Average RMSE is  0.8330370854026432
# Average RMSE is  0.8371681212810067
# Average RMSE is  0.8384338115685537
# Average RMSE is  0.8386723112908362
# Average RMSE is  0.8407834127821259
# ...

# %%
# Plot of average RMSE vs K
plt.figure(figsize=(15,5))
plot = plt.plot(range(1,26), rmse, color = 'c')
plt.axhline(y = min(rmse), c = 'r', alpha = 0.3)
plt.title('Plot of RMSE vs K for KNN algorithm', fontsize=20)
plt.xlabel('K', fontsize=15)
plt.ylabel('Average RMSE', fontsize=15)
plt.show()

# %% [markdown]
# **Answer: We see that we have a very high RMSE value when K is 1 or 2. However, as we increase K to 5, their is a sharp decrease in RMSE. Beyond K = 5, the RMSE again starts to increase. Therefore, we can say that there is a sweet spot for K which ensures a low RMSE and therefore we must select appropriate value for K. For our model, K = 5 is the best choice.**
